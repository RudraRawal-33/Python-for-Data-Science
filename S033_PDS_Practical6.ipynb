# %% [markdown]
# **Python for Data Science**
#
# **Practical VI**

# %% [markdown]
# Name: Rudra Rawal
#
# RollNo.: S033

# %% [markdown]
# Class: SYIT
#
# Batch: 1

# %% [markdown]
# Date of assignment: 19-08-2026
#
# Date of Submission: 19-08-2026

# %% [markdown]
# **6a. Write a Python program to import a CSV dataset using Pandas and
# display the first 5 and last 5 records.**

# %%
import pandas as pd

# %%
df = pd.read_csv("Students.csv")
print(df)
# Out:
#    Roll No     Name Department  Marks  Attendance
# 0       15   Vedant     BSc IT     78          85
# 1       19   Sumeet     BSc CS     65          90
# 2       32    Niraj     BSc IT     88          92
# 3       33    Rudra     BSc CS     72          80
# 4       36  Harshal     BSc IT     55          70
# 5       38      Jay      BAMMC     86          90
# 6       42     Jack      B COM     42          50
# 7       48   Deepak     BSc CS     96          44
# 8       50    Vinod     BSc BT     76          72

# %% [markdown]
# **Print top 5 values**

# %%
print(df.head())
# Out:
#    Roll No     Name Department  Marks  Attendance
# 0       15   Vedant     BSc IT     78          85
# 1       19   Sumeet     BSc CS     65          90
# 2       32    Niraj     BSc IT     88          92
# 3       33    Rudra     BSc CS     72          80
# 4       36  Harshal     BSc IT     55          70

# %% [markdown]
# **Print last 5 values**

# %%
print(df.tail())
# Out:
#    Roll No     Name Department  Marks  Attendance
# 4       36  Harshal     BSc IT     55          70
# 5       38      Jay      BAMMC     86          90
# 6       42     Jack      B COM     42          50
# 7       48   Deepak     BSc CS     96          44
# 8       50    Vinod     BSc BT     76          72

# %% [markdown]
# **6B.Write a Python program to analyze the dataset by displaying the number of
# rows and columns, column names, data types, and basic statistical information.**

# %% [markdown]
# **Display Number of row and column**

# %%
print(df.shape)
# Out:
# (9, 5)

# %% [markdown]
# **Display Column Names**

# %%
print(df.columns)
# Out:
# Index(['Roll No', 'Name', 'Department', 'Marks', 'Attendance'], dtype='object')

# %% [markdown]
# **Display Data types**

# %%
print(df.dtypes)
# Out:
# Roll No        int64
# Name          object
# Department    object
# Marks          int64
# Attendance     int64
# dtype: object

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of    Roll No     Name Department  Marks  Attendance
# 0       15   Vedant     BSc IT     78          85
# 1       19   Sumeet     BSc CS     65          90
# 2       32    Niraj     BSc IT     88          92
# 3       33    Rudra     BSc CS     72          80
# 4       36  Harshal     BSc IT     55          70
# 5       38      Jay      BAMMC     86          90
# 6       42     Jack      B COM     42          50
# 7       48   Deepak     BSc CS     96          44
# 8       50    Vinod     BSc BT     76          72>

# %%
print(df.describe())
# Out:
#          Roll No      Marks  Attendance
# count   9.000000   9.000000    9.000000
# mean   34.777778  73.111111   74.777778
# std    11.840373  16.981199   17.619434
# min    15.000000  42.000000   44.000000
# 25%    32.000000  65.000000   70.000000
# 50%    36.000000  76.000000   80.000000
# 75%    42.000000  86.000000   90.000000
# max    50.000000  96.000000   92.000000

# %% [markdown]
# **6c. Write a Python program to filter records from the dataset using
# conditions. For example, display students having marks greater than 60 or
# employees having salary greater than 40,000.**

# %%
result = df[df["Attendance"]>=90]
print(result)
# Out:
#    Roll No    Name Department  Marks  Attendance
# 1       19  Sumeet     BSc CS     65          90
# 2       32   Niraj     BSc IT     88          92
# 5       38     Jay      BAMMC     86          90

# %% [markdown]
# **6d. Write a Python program to sort the dataset based on a selected column
# and display the top 5 records. For example, sort students by marks or products
# by price.**

# %%
result = df.sort_values("Marks", ascending=False)
print(result)
# Out:
#    Roll No     Name Department  Marks  Attendance
# 7       48   Deepak     BSc CS     96          44
# 2       32    Niraj     BSc IT     88          92
# 5       38      Jay      BAMMC     86          90
# 0       15   Vedant     BSc IT     78          85
# 8       50    Vinod     BSc BT     76          72
# 3       33    Rudra     BSc CS     72          80
# 1       19   Sumeet     BSc CS     65          90
# 4       36  Harshal     BSc IT     55          70
# 6       42     Jack      B COM     42          50

# %% [markdown]
# **6e. Write a Python program to perform data analysis on the dataset by
# finding the maximum, minimum, average, and total values of a numerical
# column.**

# %%
print("Maximum Marks ",df["Marks"].max())
print("Minimum Marks ",df["Marks"].min())
# Out:
# Maximum Marks  96
# Minimum Marks  42
